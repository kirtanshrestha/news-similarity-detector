# %%
import pandas as pd

fake = pd.read_csv('fake.csv')
fake['target']='fake'

real = pd.read_csv('true.csv')
real['target']='real'

df = pd.concat([fake,real],ignore_index=True)[['title','text','target']]

df = df.dropna().reset_index(drop=True)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

df['combined']=df['title']+" "+df['text']

vectorizer = TfidfVectorizer(stop_words='english',max_features=10000)
tfidf_matrix = vectorizer.fit_transform(df['combined'])

from sklearn.metrics.pairwise import cosine_similarity

cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

threshold = 0.7
duplicates = []

# %%
for i in range(len(df)):
    for j in range(i + 1, len(df)):
        if cosine_sim[i, j] >= threshold:
            duplicates.append((i, j, cosine_sim[i, j]))

print("Potential duplicate article pairs:", len(duplicates))
# Out:
# Potential duplicate article pairs: 11359

# %%
for i, j, score in duplicates[:10]:
    print(f"\nArticle {i} & {j} → {score:.2f}")
    print("Title 1:", df.loc[i, 'title'])
    print("Title 2:", df.loc[j, 'title'])
# Out:
# Article 1409 & 27579 → 0.81
# Title 1:  Trump’s FCC Will Decimate Internet Freedom (VIDEO)
# Title 2: FCC chairman expected to unveil strategy to reverse net neutrality: sources
#
# Article 1488 & 1535 → 0.99
# Title 1:  McConnell Says He’ll Obstruct ANY Effort To Hire Independent Special Prosecutor
# Title 2:  McConnell Says He’ll Obstruct ANY Effort To Hire Independent Special Prosecutor
#
# Article 1591 & 14401 → 0.81
# Title 1:  Democrats Chant Warning To GOP As Trumpcare Passes: Na Na Na Na, Hey Hey Hey, Goodbye! (VIDEO)
# Title 2: BEST 10 SECONDS OF YOUR DAY: Watch Al Sharpton Say He’ll Leave The U.S. If Trump Is Elected
#
# Article 1591 & 20941 → 0.81
# Title 1:  Democrats Chant Warning To GOP As Trumpcare Passes: Na Na Na Na, Hey Hey Hey, Goodbye! (VIDEO)
# Title 2: BEST 10 SECONDS OF YOUR DAY: Watch Al Sharpton Say He’ll Leave The U.S. If Trump Is Elected
#
# Article 3415 & 12129 → 0.85
# Title 1:  Not A Single D.C. Public School Marching Band Will Participate In Trump’s Inauguration
# Title 2: D.C. MARCHING BANDS NOT SHOWING For Inauguration…It’s OK, There’s A Better Solution!
#
# Article 3794 & 30750 → 0.80
# Title 1:  Former Candidate Ben Carson Declines Trump Cabinet Position, Cites Lack Of Experience
# Title 2: Republican Ben Carson opts against job in Trump Cabinet
#
# Article 3984 & 12536 → 0.83
# Title 1:  Federal Judge Demands RNC Reveal Details Of Voter Intimidation Pact With Trump
# Title 2: BREAKING: OBAMA APPOINTED JUDGE Demands RNC Reveal Trump’s Plans To Prevent Voter Fraud
#
# Article 3984 & 19696 → 0.83
# Title 1:  Federal Judge Demands RNC Reveal Details Of Voter Intimidation Pact With Trump
# Title 2: BREAKING: OBAMA APPOINTED JUDGE Demands RNC Reveal Trump’s Plans To Prevent Voter Fraud
#
# Article 4390 & 31427 → 0.81
# Title 1:  Hillary Clinton Talks Racism In Charlotte: ‘My Worries Aren’t The Same As Black Grandmothers’ (VIDEO)
# Title 2: Clinton: My worries are not the same as black grandmothers'
#
# Article 5357 & 5446 → 0.87
# Title 1:  Elizabeth Warren Gives Trump Bad News After He Mocks Her For Not Getting VP Spot (TWEETS)
# Title 2:  Elizabeth Warren BURIES Trump After He Throws Temper Tantrum Over Her Attacks
